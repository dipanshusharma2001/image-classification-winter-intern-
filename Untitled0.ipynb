# %%
import torch 
import torchvision 

import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import numpy as np

# %%
device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(device)
# Out:
# cuda

# %%
transform = transforms.Compose(
    [transforms.Resize((64,64)),
     transforms.ToTensor(),
     transforms.Normalize((0.5,0.5,0.5),(0.5,0.5,0.5))]
)

# %%
trainset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform)
# Out:
# Files already downloaded and verified

# %%
trainloader = torch.utils.data.DataLoader(trainset, batch_size = 48, shuffle = True)
testset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size = 48, shuffle = False)
classes = ('plane', 'car','bird','cat','deer','dog','frog','horse','ship','truck')
# Out:
# Files already downloaded and verified

# %%
def imageshow(img):
  img= img /2 + 0.5
  npimg = img.numpy()
  plt.imshow(np.transpose(npimg,(1,2,0)))

# get some random training images 
dataiter = iter(trainloader)
images , labels = dataiter.next()

# show images 
imageshow(torchvision.utils.make_grid(images))

# print labels 

print (" ".join('%5s' % classes[labels[j]] for j in range (48)))
# Out:
#  deer   cat   car   cat truck  bird plane  deer  deer  frog   car  deer horse truck truck  deer plane truck  frog plane horse   dog plane truck   car  ship  ship   dog horse  bird   car horse  frog   cat   cat   dog  ship   dog  bird truck  deer horse plane  deer   dog  bird   car   cat

# %%
# define a convolution network

import torch.nn as nn


class Net(nn.Module):
      def __init__(self):
        """CNN Builder."""
        super(Net, self).__init__()

        self.conv_layer = nn.Sequential(

            # Conv Layer block 1
            nn.Conv2d(in_channels=3, out_channels=32, kernel_size=3, padding=1),
            nn.BatchNorm2d(32),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            # Conv Layer block 2
            nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding=1),
            nn.BatchNorm2d(128),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=128, out_channels=128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Dropout2d(p=0.05),

            # Conv Layer block 3
            nn.Conv2d(in_channels=128, out_channels=256, kernel_size=3, padding=1),
            nn.BatchNorm2d(256),
            nn.ReLU(inplace=True),
            nn.Conv2d(in_channels=256, out_channels=256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )


        self.fc_layer = nn.Sequential(
            nn.Dropout(p=0.1),
            nn.Linear(4096*4, 1024),
            nn.ReLU(inplace=True),
            nn.Linear(1024, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(p=0.1),
            nn.Linear(512, 10)
        )


      def forward(self, x):
        """Perform forward."""
        
        # conv layers
        x = self.conv_layer(x)
        
        # flatten
        x = x.view(x.size(0), -1)
        
        # fc layer
        x = self.fc_layer(x)

        return x

net = Net().to(device)

# %%
import torch.optim as optim 

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.001, weight_decay = 0.0001)

# %%
from torch.autograd import Variable

for epoch in range(25):

  running_loss = 0.0
  for i,(images,labels) in enumerate(trainloader):

    if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())

    optimizer.zero_grad()

    outputs = net(images)
    loss = criterion(outputs,labels)
    running_loss += loss
    loss.backward()
    optimizer.step()

  print(running_loss/len(trainloader))

print ("finished running")
# Out:
# tensor(2.2095, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.7779, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.5264, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3939, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.3025, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.2241, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.1554, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0959, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(1.0383, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9860, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.9393, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8934, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8557, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.8189, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7872, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7569, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7293, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.7052, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6806, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6580, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6405, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6173, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.6001, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5821, device='cuda:0', grad_fn=<DivBackward0>)
# tensor(0.5610, device='cuda:0', grad_fn=<DivBackward0>)
# finished running

# %%
dataiter = iter(testloader)
images, labels = dataiter.next()

# print images 
imageshow(torchvision.utils.make_grid(images))

print ("ground truth : " ,''.join('%5s'% classes[labels[j]] for j in range(48)))

if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda())


outputs = net(images)

_,predicted = torch.max(outputs.data,1)

print ("predicted : " ,''.join('%5s'% classes[predicted[j]] for j in range(48)))


correct = 0
total =0
with torch.no_grad():
  for data in testloader:
    images, labels = data
    if torch.cuda.is_available():
            images=Variable(images.cuda())
            labels=Variable(labels.cuda()) 
    outputs = net(images)
    _,predicted = torch.max(outputs,1)
    total+=labels.size(0)
    correct+=(predicted==labels).sum().item()

print (total)
print (correct)
print ("accuracy of the network on the 10000 test images: %d %%" %(100*correct/total))
# Out:
# ground truth :    cat ship shipplane frog frog  car frog  cat  carplanetruck  doghorsetruck ship  doghorse ship froghorseplane deertruck  dog bird deerplanetruck frog frog  dog deer  dogtruck bird deer  cartruck  dog deer frog  dog frogplanetruck  cattruck
# predicted :    cat ship shipplane frog frog  car deer  cat  carplanetruck  doghorsetruck ship  doghorse ship froghorseplane birdtruck deer frog birdplanetruck frog frog  dog bird  cattruck  cat deertrucktruck  dogplane frog  cat frogplanetruck  cattruck
# 10000
# 7526
# accuracy of the network on the 10000 test images: 75 %
